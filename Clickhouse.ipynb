# %%
client = Client(host='58.198.176.249',user = "default", database="github_log", password='811102ysh')

# %%
Client?
# Out:
# Init signature: Client(*args, **kwargs)
# Docstring:
# Client for communication with the ClickHouse server.
# Single connection is established per each connected instance of the client.
#
# :param settings: Dictionary of settings that passed to every query.
#                  Defaults to ``None`` (no additional settings). See all
#                  available settings in `ClickHouse docs
#                  <https://clickhouse.yandex/docs/en/single/#settings>`_.
#
# Driver's settings:
#
#     * insert_block_size -- chunk size to split rows for ``INSERT``.
#       Defaults to ``1048576``.
#
#     * strings_as_bytes -- turns off string column encoding/decoding.
# File:           d:\tianyi\anaconda3\envs\pycharm\lib\site-packages\clickhouse_driver\client.py
# Type:           type
# Subclasses:

# %%
from clickhouse_driver import Client
from pandas.core.frame import DataFrame
client = Client(host='58.198.176.249',user = "default", database="github_log", password='811102ysh')
result = client.execute("select type from github_log.year2019 where type='PushEvent' limit 1")
result2 = client.execute("select push_commits from github_log.year2019 where type='PushEvent' limit 1")

# %%
import pprint
print (result)
print (result2)
pprint.pprint (type(result))
# Out:
# [('PushEvent',)]
# ...

# %%
sql = '''SELECT JSONExtractRaw('{"sha": "6139e8b97ffcc0928deffbf4d7423885862ad48a","author": {"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"}, "message":"Checkpoint\n\nTurning on indexing strict mode", "distinct":true, "url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/6139e8b97ffcc0928deffbf4d7423885862ad48a"}','author')'''
sql2 = """ SELECT JSONExtractRaw('{"a": "hello", "c": "hello","d":true, "b": {"t":"t"}}', 'd') """
result = client.execute(sql)
pprint.pprint (result)
# Out:
# [('',)]

# %%
import sqlalchemy as sa
import pandas as pd
cdb_engine  = sa.create_engine('clickhouse://publickuser:xlab@ecnu@58.198.176.249:8123/github')
print (cdb_engine)
# Out:
# Engine(clickhouse://publickuser:***@58.198.176.249:8123/github)

# %%
sql = """select * from github.operation_2019 limit 1"""
result = pd.read_sql(sql,cdb_engine)
result
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-3b5bea1fcfa0> in <module>
#       1 sql = """select * from github.operation_2019 limit 1"""
# ----> 2 result = pd.read_sql(sql,cdb_engine)
#       3 result
#
# D:\Tianyi\Anaconda3\envs\Pycharm\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     434             coerce_float=coerce_float,
#     435             parse_dates=parse_dates,
# --> 436             chunksize=chunksize,
#     437         )
#     438
#
# D:\Tianyi\Anaconda3\envs\Pycharm\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ...

# %%
"""
SELECT repo_id, anyLast(repo_name) as repo_name,  JSONExtractString(JSONExtractRaw(arrayJoin(JSONExtractArrayRaw(push_commits)), 'author'), 'email') as email FROM github_log.year2019 WHERE type = 'PushEvent' AND push_commits != '' AND endsWith(email, 'huawei.com') GROUP BY repo_id, email

"""
# Out:
# "\nSELECT repo_id, anyLast(repo_name) as repo_name,  JSONExtractString(JSONExtractRaw(arrayJoin(JSONExtractArrayRaw(push_commits)), 'author'), 'email') as email FROM github_log.year2019 WHERE type = 'PushEvent' AND push_commits != '' AND endsWith(email, 'huawei.com') GROUP BY repo_id, email\n\n"

# %%
SELECT JSONExtractString(JSONExtractRaw(arrayJoin(JSONExtractArrayRaw('''{"sha":"c9f6daecdad50040b46707db82884801bb79f0de","author":{"name":"Godfrey Chan","email":"0966a165cff09fd9b0dd27fd6a2242e2aeba351e@gmail.com"},"message":"zomg\n\nCo-authored-by: Robert Jackson <me@rwjblue.com>","distinct":true,"url":"https://api.github.com/repos/emberjs/ember.js/commits/c9f6daecdad50040b46707db82884801bb79f0de"}''')), 'author'), 'email') as email
# Out:
#   File "<ipython-input-86-42808cb6ed6f>", line 1
#     SELECT JSONExtractString(JSONExtractRaw(arrayJoin(JSONExtractArrayRaw('''[{"sha":"c9f6daecdad50040b46707db82884801bb79f0de","author":{"name":"Godfrey Chan","email":"0966a165cff09fd9b0dd27fd6a2242e2aeba351e@gmail.com"},"message":"zomg\n\nCo-authored-by: Robert Jackson <me@rwjblue.com>","distinct":true,"url":"https://api.github.com/repos/emberjs/ember.js/commits/c9f6daecdad50040b46707db82884801bb79f0de"}]''')), 'author'), 'email') as email
#                            ^
# SyntaxError: invalid syntax

# %%
SELECT JSONExtractString(JSONExtractRaw(arrayJoin(JSONExtractArrayRaw('[{"sha":"da9824228a630411543ff03ed140c5542d4c9f20","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Checkpoint before restructure","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/da9824228a630411543ff03ed140c5542d4c9f20"},{"sha":"a5df0e2a7d967e43bfad96181c70eadf60ef8490","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parses blocks","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/a5df0e2a7d967e43bfad96181c70eadf60ef8490"},{"sha":"f1b019e0abc8408cff97e6317e77d80e646e4cfd","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parser tests pass","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/f1b019e0abc8408cff97e6317e77d80e646e4cfd"},{"sha":"1a67d2f23706f7d930ee67307164247220e1f404","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Else passes","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/1a67d2f23706f7d930ee67307164247220e1f404"}]')), 'author'), 'email') as email

# %%
SELECT JSONExtractString(JSONExtractRaw(arrayJoin(JSONExtractArrayRaw('[{"sha":"da9824228a630411543ff03ed140c5542d4c9f20","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Checkpoint before restructure","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/da9824228a630411543ff03ed140c5542d4c9f20"},{"sha":"a5df0e2a7d967e43bfad96181c70eadf60ef8490","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parses blocks","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/a5df0e2a7d967e43bfad96181c70eadf60ef8490"},{"sha":"f1b019e0abc8408cff97e6317e77d80e646e4cfd","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parser tests pass","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/f1b019e0abc8408cff97e6317e77d80e646e4cfd"},{"sha":"1a67d2f23706f7d930ee67307164247220e1f404","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Else passes","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/1a67d2f23706f7d930ee67307164247220e1f404"}]')), 'author'), 'email') as email
# Out:
# Failed to connect to 58.198.176.146:9000
# Traceback (most recent call last):
#   File "D:\Tianyi\Anaconda3\envs\Pycharm\lib\site-packages\clickhouse_driver\connection.py", line 256, in connect
#     return self._init_connection(host, port)
#   File "D:\Tianyi\Anaconda3\envs\Pycharm\lib\site-packages\clickhouse_driver\connection.py", line 226, in _init_connection
#     self.socket = self._create_socket(host, port)
#   File "D:\Tianyi\Anaconda3\envs\Pycharm\lib\site-packages\clickhouse_driver\connection.py", line 221, in _create_socket
#     raise err
#   File "D:\Tianyi\Anaconda3\envs\Pycharm\lib\site-packages\clickhouse_driver\connection.py", line 212, in _create_socket
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
# ---------------------------------------------------------------------------
# NetworkError                              Traceback (most recent call last)
# <ipython-input-95-a41f5a17c44a> in <module>
#       1 #connect the node 4
# ...

# %%
SELECT JSONExtractArrayRaw('[{"sha":"da9824228a630411543ff03ed140c5542d4c9f20","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Checkpoint before restructure","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/da9824228a630411543ff03ed140c5542d4c9f20"},{"sha":"a5df0e2a7d967e43bfad96181c70eadf60ef8490","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parses blocks","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/a5df0e2a7d967e43bfad96181c70eadf60ef8490"},{"sha":"f1b019e0abc8408cff97e6317e77d80e646e4cfd","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parser tests pass","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/f1b019e0abc8408cff97e6317e77d80e646e4cfd"},{"sha":"1a67d2f23706f7d930ee67307164247220e1f404","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Else passes","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/1a67d2f23706f7d930ee67307164247220e1f404"}]')

# %%
SELECT arrayJoin(JSONExtractArrayRaw('[{"sha":"da9824228a630411543ff03ed140c5542d4c9f20","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Checkpoint before restructure","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/da9824228a630411543ff03ed140c5542d4c9f20"},{"sha":"a5df0e2a7d967e43bfad96181c70eadf60ef8490","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parses blocks","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/a5df0e2a7d967e43bfad96181c70eadf60ef8490"},{"sha":"f1b019e0abc8408cff97e6317e77d80e646e4cfd","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parser tests pass","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/f1b019e0abc8408cff97e6317e77d80e646e4cfd"},{"sha":"1a67d2f23706f7d930ee67307164247220e1f404","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Else passes","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/1a67d2f23706f7d930ee67307164247220e1f404"}]'))

# %%
SELECT JSONExtractRaw(arrayJoin(JSONExtractArrayRaw('[{"sha":"da9824228a630411543ff03ed140c5542d4c9f20","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Checkpoint before restructure","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/da9824228a630411543ff03ed140c5542d4c9f20"},{"sha":"a5df0e2a7d967e43bfad96181c70eadf60ef8490","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parses blocks","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/a5df0e2a7d967e43bfad96181c70eadf60ef8490"},{"sha":"f1b019e0abc8408cff97e6317e77d80e646e4cfd","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Parser tests pass","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/f1b019e0abc8408cff97e6317e77d80e646e4cfd"},{"sha":"1a67d2f23706f7d930ee67307164247220e1f404","author":{"name":"Yehuda Katz","email":"6cca45edf25d9f6c44ec8f2aa59ba63f92457e1b@gmail.com"},"message":"Else passes","distinct":true,"url":"https://api.github.com/repos/glimmerjs/glimmer-vm/commits/1a67d2f23706f7d930ee67307164247220e1f404"}]')), 'author')

# %%
class Weight():
    def __init__(self,weights):
        self.issueCommentWeight=1
        self.openIssueWeight=2
        self.openPullWeight=3
        self.pullReviewWeight=4
        self.mergePullWeight=5
    def culculate_weight():
        #culculate weights in different way
        pass
    
weight = Weight()
weight.issueCommentWeight
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-a939e35d4b1e> in <module>
#      10         pass
#      11
# ---> 12 weight = Weight()
#      13 weight.issueCommentWeight
#
# TypeError: __init__() missing 1 required positional argument: 'weights'

# %%
db ='github_log'
table ='year2019'
topN = 10000
repo_activity_sql = '''
SELECT contribute_list.repo_id AS repo_id, round(sum(sqrt(contribute_list.score)),2) AS repo_activity 
FROM
(SELECT
icc.repo_id AS repo_id, icc.actor_id AS actor_id, {issueCommentWeight}*icc.count+{openIssueWeight}*oic.count+{openPullWeight}*opc.count+{pullReviewWeight}*rcc.count+{mergePullWeight}*mpc.count AS score
FROM
(SELECT repo_id, actor_id, COUNT(*) count FROM {db}.{table} WHERE type='IssueCommentEvent' AND action='created' GROUP BY repo_id, actor_id) AS icc
LEFT JOIN
(SELECT repo_id, actor_id, COUNT(*) count FROM {db}.{table} WHERE type='IssuesEvent' AND action='opened' GROUP BY repo_id, actor_id) AS oic
ON icc.repo_id=oic.repo_id AND icc.actor_id=oic.actor_id 
LEFT JOIN
(SELECT repo_id, actor_id, COUNT(*) count FROM {db}.{table} WHERE type='PullRequestEvent' AND action='opened' GROUP BY repo_id, actor_id) AS opc
ON icc.repo_id=opc.repo_id AND icc.actor_id=opc.actor_id 
LEFT JOIN
(SELECT repo_id, actor_id, COUNT(*) count FROM {db}.{table} WHERE type='PullRequestReviewCommentEvent' AND action='created' GROUP BY repo_id, actor_id) AS rcc
ON icc.repo_id=rcc.repo_id AND icc.actor_id=rcc.actor_id
LEFT JOIN
(SELECT repo_id, issue_author_id AS actor_id, COUNT(*) as count FROM {db}.{table} WHERE type='PullRequestEvent' AND action='closed' AND pull_merged=1 GROUP BY repo_id, actor_id) AS mpc
ON icc.repo_id=mpc.repo_id AND icc.actor_id=mpc.actor_id) AS contribute_list
GROUP BY repo_id
ORDER BY repo_activity DESC
LIMIT {topN}
'''.format(issueCommentWeight=weight.issueCommentWeight,openIssueWeight=weight.openIssueWeight,openPullWeight=weight.openPullWeight,pullReviewWeight=weight.pullReviewWeight,mergePullWeight=weight.mergePullWeight,db=db,table=table,topN=topN)
print (repo_activity_sql)
# Out:
# SELECT contribute_list.repo_id AS repo_id, round(sum(sqrt(contribute_list.score)),2) AS repo_activity
# FROM
# (SELECT
# icc.repo_id AS repo_id, icc.actor_id AS actor_id, 1*icc.count+2*oic.count+3*opc.count+4*rcc.count+5*mpc.count AS score
# FROM
# (SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='IssueCommentEvent' AND action='created' GROUP BY repo_id, actor_id) AS icc
# LEFT JOIN
# (SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='IssuesEvent' AND action='opened' GROUP BY repo_id, actor_id) AS oic
# ON icc.repo_id=oic.repo_id AND icc.actor_id=oic.actor_id
# LEFT JOIN
# (SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='PullRequestEvent' AND action='opened' GROUP BY repo_id, actor_id) AS opc
# ON icc.repo_id=opc.repo_id AND icc.actor_id=opc.actor_id
# LEFT JOIN
# ...

# %%
sql_issue_created = """
Select repo_id, repo_name, count(*) as issue_count from github_log.year2019 where type='IssueCommentEvent' and action = 'created' group by repo_id, actor_id, repo_name 
order by issue_count desc
limit 100
"""
sql_push = """
select *  from github_log.year2019 where type='PushEvent' limit 2
"""

# %%
# %%time
from clickhouse_driver import Client
from pandas.core.frame import DataFrame
client = Client(host='58.198.176.146',database="github_log")
result = client.execute(repo_activity_sql)
# Out:
# Wall time: 1min 27s

# %%
#result = DataFrame(result)
len(result)
# Out:
# 10000

# %%
result
# Out:
# [(31792824, 27281.91),
#  (41881900, 26145.14),
#  (72685026, 24635.55),
#  (20580498, 21477.5),
#  (45717250, 19645.75),
#  (177736533, 18781.83),
#  (12888993, 16381.35),
#  (3638964, 15423.78),
#  (4542716, 13974.96),
#  (46806184, 13879.87),
#  (36040894, 13256.81),
#  (29028775, 12585.92),
#  (65600975, 12098.25),
#  (6093316, 12035.93),
#  (17620347, 10978.96),
#  (724712, 10207.43),
#  (23096959, 9876.84),
#  (7833168, 9868.82),
#  (2884111, 9687.32),
#  (24195339, 9048.27),
#  (15634981, 9018.21),
#  (20929025, 8653.15),
#  (26295345, 8568.96),
#  (51478266, 8012.22),
#  (74175805, 7773.15),
#  (858127, 7052.38),
#  (15111821, 7044.21),
#  (507775, 6883.08),
#  (80862584, 6688.53),
#  (23083156, 6597.11),
#  (458058, 6555.13),
#  (19745004, 6518.32),
#  (34526884, 6441.22),
#  (52855516, 6339.68),
#  (27193779, 6293.9),
#  (2200856, 6292.43),
#  (59771425, 6202.26),
#  (5973855, 6150.4),
#  (93444615, 6051.92),
#  (60243197, 5889.94),
#  (9384267, 5844.7),
# ...

# %%
sql SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='IssueCommentEvent' AND action='created' GROUP BY repo_id, actor_id limit 100000;

# %%
SELECT icc.repo_id AS repo_id, icc.actor_id AS actor_id, 1*icc.count+2*oic.count+3*opc.count+4*rcc.count+5*mpc.count AS score
FROM
(SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='IssueCommentEvent' AND action='created' GROUP BY repo_id, actor_id) AS icc
LEFT JOIN
(SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='IssuesEvent' AND action='opened' GROUP BY repo_id, actor_id) AS oic
ON icc.repo_id=oic.repo_id AND icc.actor_id=oic.actor_id 
LEFT JOIN
(SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='PullRequestEvent' AND action='opened' GROUP BY repo_id, actor_id) AS opc
ON icc.repo_id=opc.repo_id AND icc.actor_id=opc.actor_id 
LEFT JOIN
(SELECT repo_id, actor_id, COUNT(*) count FROM github_log.year2019 WHERE type='PullRequestReviewCommentEvent' AND action='created' GROUP BY repo_id, actor_id) AS rcc
ON icc.repo_id=rcc.repo_id AND icc.actor_id=rcc.actor_id
LEFT JOIN
(SELECT repo_id, issue_author_id AS actor_id, COUNT(*) as count FROM github_log.year2019 WHERE type='PullRequestEvent' AND action='closed' AND pull_merged=1 GROUP BY repo_id, actor_id) AS mpc
ON icc.repo_id=mpc.repo_id AND icc.actor_id=mpc.actor_id
# Out:
#   File "<ipython-input-38-dc760c3b1c68>", line 1
#     SELECT icc.repo_id AS repo_id, icc.actor_id AS actor_id, 1*icc.count+2*oic.count+3*opc.count+4*rcc.count+5*mpc.count AS score
#              ^
# SyntaxError: invalid syntax

# %%
sql ='"
SELECT repo_id,repo_name, repo_description, repo_size, repo_forks_count, repo_language, repo_has_issues, repo_has_projects, repo_license, repo_created_at FROM github_log.year2019 WHERE type="PullRequestEvent" limit 10000
"'

# %%
sql_distinct_repo="""
    select distinct repo_id from github_log.year2019 
"""
result_distinct_repo =  client.execute(sql_distinct_repo)
data= DataFrame(result_distinct_repo)
data
# Out:
#                   0
# 0           8385616
# 1         189342031
# 2         205000378
# 3         210903466
# 4           7876204
# ...             ...
# 39722807  168602898
# 39722808  168603251
# 39722809  144556374
# 39722810  168603433
# 39722811  168603555
#
# [39722812 rows x 1 columns]

# %%
data.rename(columns={0:'repo_id'},inplace=True)
data
# Out:
#             repo_id
# 0           8385616
# 1         189342031
# 2         205000378
# 3         210903466
# 4           7876204
# ...             ...
# 39722807  168602898
# 39722808  168603251
# 39722809  144556374
# 39722810  168603433
# 39722811  168603555
#
# [39722812 rows x 1 columns]

# %%
sql ='''
select distinct repo_id,repo_name,repo_description, char_length(repo_description) as length,repo_forks_count from github_log.year2019 where length>0 order by length DESC limit 100 
'''
result = client.execute(sql)
# Out:
# WARNING:clickhouse_driver.connection:Error on 58.198.176.249:9000 ping: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
# WARNING:clickhouse_driver.connection:Connection was closed, reconnecting.

# %%
result
# Out:
# [(218028472,
#   'Geronimo1973/Help-me-get-rid-of-unhumans',
# ...

# %%
from pandas.core.frame import DataFrame
data= DataFrame(result)
data.rename(columns={0:'repo_id',1:'repo_name',2:'repo_description',3:'repo_description_length',4:'repo_fork_count'},inplace=True)
data
# Out:
#       repo_id                                          repo_name  \
# 0   218028472           Geronimo1973/Help-me-get-rid-of-unhumans
# 1   228146483                                      hortarym123/1
# 2   161056670  SilverCory/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# 3   161059340  NotWeeb/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# 4   160841951  LuanDevecchi/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# ..        ...                                                ...
# 95  215288867                                 marnoseiha/Hackcam
# 96  199386340                              chfucao/chifuyidaocao
# 97   32470454                    cuci-karpet/cuci-karpet-jakarta
# 98  227580010                       Noorrama/cuci-karpet-jakarta
# 99   32470454                    cuci-karpet/cuci-karpet-jakarta
#
#                                      repo_description  \
# 0   /* JS */ gapi.loaded_0(function(_){var window=...
# 1   <!doctype html> <html lang="en"> <head>     <t...
# ...

# %%
data
# Out:
#             0                                                  1  \
# 0   218028472           Geronimo1973/Help-me-get-rid-of-unhumans
# 1   228146483                                      hortarym123/1
# 2   161059340  NotWeeb/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# 3   161180474  lipusal/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# 4   161059340  NotWeeb/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee...
# ..        ...                                                ...
# 95  215288867                                 marnoseiha/Hackcam
# 96  199386340                              chfucao/chifuyidaocao
# 97  227580010                       Noorrama/cuci-karpet-jakarta
# 98   32470454                    cuci-karpet/cuci-karpet-jakarta
# 99   32470454                    cuci-karpet/cuci-karpet-jakarta
#
#                                                     2  3       4
# 0   /* JS */ gapi.loaded_0(function(_){var window=...  0  139142
# ...

# %%
 select * from (select ROW_NUMBER()over(partition by Aid order by BidTime desc) rowId,* 
       from auto_AuctionRecords where Uid=353) as AuctionRecords 
       where rowId=1
        
"""
select repo_id,repo_name,repo_description, char_length(repo_description) as length from (select ROW_NUMBER() over (partition by repo_id order by created_at desc) rowId, *
                from github_log.year2019 where type="PullRequestEvent") as AuctionRecords
                where rowID =1
"""

# %%
from clickhouse_driver import Client
from pandas.core.frame import DataFrame
client = Client(host='58.198.176.146',user = "default", database="github_log")
result = client.execute("select count(*) from github_log.year2019")
print (result)
# Out:
# WARNING:clickhouse_driver.connection:Failed to connect to 58.198.176.146:9000
# Traceback (most recent call last):
#   File "D:\Tianyi\Anaconda3\lib\site-packages\clickhouse_driver\connection.py", line 256, in connect
#     return self._init_connection(host, port)
#   File "D:\Tianyi\Anaconda3\lib\site-packages\clickhouse_driver\connection.py", line 226, in _init_connection
#     self.socket = self._create_socket(host, port)
#   File "D:\Tianyi\Anaconda3\lib\site-packages\clickhouse_driver\connection.py", line 221, in _create_socket
#     raise err
#   File "D:\Tianyi\Anaconda3\lib\site-packages\clickhouse_driver\connection.py", line 212, in _create_socket
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
# ---------------------------------------------------------------------------
# NetworkError                              Traceback (most recent call last)
# <ipython-input-37-d956d7be0201> in <module>
# ...
